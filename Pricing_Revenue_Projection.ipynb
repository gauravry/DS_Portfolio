# %% [markdown]
# <a href="https://colab.research.google.com/github/gauravry/DS_Portfolio/blob/main/Pricing_Revenue_Projection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of iterations for the simulation
num_iterations = 10000

# Parameters for the units sold distribution
units_sold_mean = 1000
units_sold_stddev = 100

# Parameters for the price per unit distribution
price_mean = 50
price_stddev = 5

# Generate random samples for units sold and price per unit
units_sold_samples = np.random.normal(units_sold_mean, units_sold_stddev, num_iterations)
price_samples = np.random.normal(price_mean, price_stddev, num_iterations)

# Calculate revenue samples
revenue_samples = units_sold_samples * price_samples

# Plotting the results
plt.hist(revenue_samples, bins=50, edgecolor='k', alpha=0.7)
plt.title('Monte Carlo Simulation of Revenue Projection')
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Summary statistics
mean_revenue = np.mean(revenue_samples)
median_revenue = np.median(revenue_samples)
stddev_revenue = np.std(revenue_samples)
percentile_5th = np.percentile(revenue_samples, 5)
percentile_95th = np.percentile(revenue_samples, 95)

print(f"Mean Revenue: ${mean_revenue:.2f}")
print(f"Median Revenue: ${median_revenue:.2f}")
print(f"Standard Deviation of Revenue: ${stddev_revenue:.2f}")
print(f"5th Percentile of Revenue: ${percentile_5th:.2f}")
print(f"95th Percentile of Revenue: ${percentile_95th:.2f}")
# Out:
# Mean Revenue: $49993.06
# Median Revenue: $49665.19
# Standard Deviation of Revenue: $7003.64
# 5th Percentile of Revenue: $38895.00
# 95th Percentile of Revenue: $61949.51
